# %%
greetings = "Hi Hello Greetings".split()

# %%
user_statement = "Hello Joshua"
user_token_sequence = user_statement.split()
user_token_sequence
# Out:
# ['Hello', 'Joshua']

# %%
if user_token_sequence[0] in greetings:
    bot_reply = "Thermonuclear War is a strange game."
    bot_reply += "The only winning move is NOT TO PLAY."
else:
    bot_reply = "Would you like to play a nice game of chess?"
bot_reply
# Out:
# 'Thermonuclear War is a strange game.The only winning move is NOT TO PLAY.'

# %%
import re

# %%
r = "(hi|hello|hey)[ ,:.!]*([a-z]*)"
re.match(r, "Hello Rosa", flags=re.IGNORECASE)
# Out:
# <re.Match object; span=(0, 10), match='Hello Rosa'>

# %%
re.match(r, "hi ho, hi ho, it's off to work ...", flags=re.IGNORECASE)
# Out:
# <re.Match object; span=(0, 5), match='hi ho'>

# %%
re.match(r, "hey, what's up", flags=re.IGNORECASE)
# Out:
# <re.Match object; span=(0, 9), match='hey, what'>

# %%
r = r"[^a-z]*([y]o|[h']?ello|ok|hey|(good[ ])(morn[gin']{0,3}|'" #the r before '(apostrophe) indicates that the quoted string literal is a raw string
r += r"afternoon|even[gin']{0,3}))[\s,;:]{1,3}([a-z]{1,20})"
    #a raw string will skip processing the backslashes and pass them on to the regular expression parser
    #otherwise, the '\s' here should be written as '\\s' to match whitespace
re_greeting = re.compile(r, flags=re.IGNORECASE) #compile so there's no need to specify flags everytime
re_greeting.match('Hello Rosa')
# Out:
# <re.Match object; span=(0, 10), match='Hello Rosa'>

# %%
re_greeting.match('Hello Rosa').groups()
# Out:
# ('Hello', None, None, 'Rosa')

# %%
re_greeting.match('Good morning Rosa')
# Out:
# <re.Match object; span=(0, 17), match='Good morning Rosa'>

# %%
re_greeting.match('Good Manning Rosa')
re_greeting.match('Good evening Rosa Parks').groups()
# Out:
# ('Good evening', 'Good ', 'evening', 'Rosa')

# %%
re_greeting.match("Good Morn'n Rosa")
# Out:
# <re.Match object; span=(0, 16), match="Good Morn'n Rosa">

# %%
re_greeting.match("yo Rosa")
# Out:
# <re.Match object; span=(0, 7), match='yo Rosa'>

# %%
my_names = set(['rosa', 'rose', 'chatty', 'chatbot', 'bot', 'chatterbot'])
curt_names = set(['hal', 'you', 'u'])
greeter_name = ''
match = re_greeting.match(input())
if match:
    at_name = match.groups()[-1]
    if at_name in curt_names:
        print("Good one.")
    elif at_name.lower() in my_names:
        print("Hi {}, How are you?".format(greeter_name))
# Out:
#  Hello Rosa
# Hi , How are you?

# %%
#represent sparse vectors as dictionaries
from collections import Counter
Counter("Guten Morgen Rosa".split())
# Out:
# Counter({'Guten': 1, 'Morgen': 1, 'Rosa': 1})

# %%
Counter("Good morning Rosa!".split())
# Out:
# Counter({'Good': 1, 'morning': 1, 'Rosa!': 1})
